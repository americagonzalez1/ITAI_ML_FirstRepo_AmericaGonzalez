# %% [markdown]
# <a href="https://colab.research.google.com/github/americagonzalez1/ITAI_ML_FirstRepo_AmericaGonzalez/blob/main/hello_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Machine Learning!")
# Out:
# Hello, Machine Learning!
